# %%
import pandas as pd
import re

# %%
hotels_df = pd.read_csv('hotels4.csv')

# %%
hotels_df
# Out:
#       Unnamed: 0                hotel_name hotel_locality  hotel_rating  \
# 0              0            Shepherd Hotel      Bethlehem           4.0
# 1              1            Shepherd Hotel      Bethlehem           4.0
# 2              2            Shepherd Hotel      Bethlehem           4.0
# 3              3            Shepherd Hotel      Bethlehem           4.0
# 4              4            Shepherd Hotel      Bethlehem           4.0
# 5              5            Shepherd Hotel      Bethlehem           4.0
# 6              6            Shepherd Hotel      Bethlehem           4.0
# 7              7            Shepherd Hotel      Bethlehem           4.0
# 8              8            Shepherd Hotel      Bethlehem           4.0
# 9              9            Shepherd Hotel      Bethlehem           4.0
# 10            10            Shepherd Hotel      Bethlehem           4.0
# 11            11            Shepherd Hotel      Bethlehem           4.0
# ...

# %%
def city(txt):
    pm = re.compile(r"Taybeh*")
    
    if pm.match(txt):
        return 'Taybeh'
    else:
        return txt

# %%
hotels_df['hotel_locality'] = hotels_df['hotel_locality'].apply(city)

# %%
hotels_df.groupby('hotel_locality').count()
# Out:
#                 Unnamed: 0  bubble_rating  hotel_name  hotel_rating  \
# hotel_locality
# Beit Jala               51             51          51            51
# Beit Sahour             16             16          16            16
# Bethlehem              722            722         722           722
# Gaza City               60             60          60            60
# Jenin                    2              2           2             2
# Jericho                102            102         102           102
# Nablus                  14             14          14            14
# Ramallah               186            186         186           186
# Taybeh                  33             33          33            33
#
#                 num_reviews_reviewer  review_body  review_date  review_title  \
# hotel_locality
# Beit Jala                         51           51           51            51
# Beit Sahour                       16           16           16            16
# ...

# %%
hotels_df

# %%
hotels_df.to_csv('hotels2.csv')

# %%
hotels_df = pd.read_csv('hotels2.csv')

# %%
hotels_df.groupby('hotel_locality').count()
# Out:
#                 Unnamed: 0  Unnamed: 0.1  bubble_rating  hotel_name  \
# hotel_locality
# Beit Jala               51            51             51          51
# Beit Sahour             16            16             16          16
# Bethlehem              722           722            722         722
# Gaza City               60            60             60          60
# Jenin                    2             2              2           2
# Jericho                102           102            102         102
# Nablus                  14            14             14          14
# Ramallah               186           186            186         186
# Taybeh                  33            33             33          33
#
#                 hotel_rating  num_reviews_reviewer  review_body  review_date  \
# hotel_locality
# Beit Jala                 51                    51           51           51
# Beit Sahour               16                    16           16           16
# ...

# %%
hotels_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  bubble_rating hotel_locality  \
# 0              0             0             10      Bethlehem
# 1              1             1             30      Bethlehem
# 2              2             2             40      Bethlehem
# 3              3             3             50      Bethlehem
# 4              4             4             30      Bethlehem
# 5              5             5             50      Bethlehem
# 6              6             6             50      Bethlehem
# 7              7             7             50      Bethlehem
# 8              8             8             40      Bethlehem
# 9              9             9             30      Bethlehem
# 10            10            10             50      Bethlehem
# 11            11            11             20      Bethlehem
# 12            12            12             40      Bethlehem
# 13            13            13             40      Bethlehem
# ...

# %%
hotels_df.rename(columns={'bubble_rating': 'review_rating'}, inplace=True)

# %%
hotels_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  review_rating hotel_locality  \
# 0              0             0             10      Bethlehem
# 1              1             1             30      Bethlehem
# 2              2             2             40      Bethlehem
# 3              3             3             50      Bethlehem
# 4              4             4             30      Bethlehem
# 5              5             5             50      Bethlehem
# 6              6             6             50      Bethlehem
# 7              7             7             50      Bethlehem
# 8              8             8             40      Bethlehem
# 9              9             9             30      Bethlehem
# 10            10            10             50      Bethlehem
# 11            11            11             20      Bethlehem
# 12            12            12             40      Bethlehem
# 13            13            13             40      Bethlehem
# ...

# %%
hotels_df = hotels_df.drop(['Unnamed: 0'], axis=1)

# %%
def fix_hotel_rating(txt):
        return int(txt[0])*10

# %%
hotels_df['hotel_rating'] = hotels_df['hotel_rating'].apply(fix_hotel_rating)

# %%
hotels_df
# Out:
#                     hotel_name hotel_locality  hotel_rating  review_date  \
# 0               Shepherd Hotel      Bethlehem           4.0         2018
# 1               Shepherd Hotel      Bethlehem           4.0         2017
# 2               Shepherd Hotel      Bethlehem           4.0         2017
# 3               Shepherd Hotel      Bethlehem           4.0         2017
# 4               Shepherd Hotel      Bethlehem           4.0         2016
# 5               Shepherd Hotel      Bethlehem           4.0         2016
# 6               Shepherd Hotel      Bethlehem           4.0         2016
# 7               Shepherd Hotel      Bethlehem           4.0         2015
# 8               Shepherd Hotel      Bethlehem           4.0         2015
# 9               Shepherd Hotel      Bethlehem           4.0         2015
# 10              Shepherd Hotel      Bethlehem           4.0         2015
# 11              Shepherd Hotel      Bethlehem           4.0         2015
# ...

# %%
def fix_user_location(txt):
    try:
        return txt.split(',')[1]
    except:
        return txt

# %%
print(fix_user_location('India'))
# Out:
# India

# %%
hotels_df['user_location'] = hotels_df['user_location'].apply(fix_user_location)

# %%
hotels_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  review_rating hotel_locality  \
# 0              0             0             10      Bethlehem
# 1              1             1             30      Bethlehem
# 2              2             2             40      Bethlehem
# 3              3             3             50      Bethlehem
# 4              4             4             30      Bethlehem
# 5              5             5             50      Bethlehem
# 6              6             6             50      Bethlehem
# 7              7             7             50      Bethlehem
# 8              8             8             40      Bethlehem
# 9              9             9             30      Bethlehem
# 10            10            10             50      Bethlehem
# 11            11            11             20      Bethlehem
# 12            12            12             40      Bethlehem
# 13            13            13             40      Bethlehem
# ...

# %%
def fix_user_location_UK(txt):
    if txt == 'UK':
        return 'United Kingdom'
    else:
        return txt

# %%
hotels_df['user_location'] = hotels_df['user_location'].apply(fix_user_location_UK)

# %%
hotels_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  review_rating hotel_locality  \
# 0              0             0             10      Bethlehem
# 1              1             1             30      Bethlehem
# 2              2             2             40      Bethlehem
# 3              3             3             50      Bethlehem
# 4              4             4             30      Bethlehem
# 5              5             5             50      Bethlehem
# 6              6             6             50      Bethlehem
# 7              7             7             50      Bethlehem
# 8              8             8             40      Bethlehem
# 9              9             9             30      Bethlehem
# 10            10            10             50      Bethlehem
# 11            11            11             20      Bethlehem
# 12            12            12             40      Bethlehem
# 13            13            13             40      Bethlehem
# ...

# %%
hotels_df = hotels_df.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %%
def fix_review_date(txt): #just the year
    try:
        return txt.split(',')[1]
    except:
        return txt

# %%
hotels_df['review_date'] = hotels_df['review_date'].apply(fix_review_date)

# %%
hotels_df
# Out:
#       review_rating hotel_locality                hotel_name  hotel_rating  \
# 0                10      Bethlehem            Shepherd Hotel            40
# 1                30      Bethlehem            Shepherd Hotel            40
# 2                40      Bethlehem            Shepherd Hotel            40
# 3                50      Bethlehem            Shepherd Hotel            40
# 4                30      Bethlehem            Shepherd Hotel            40
# 5                50      Bethlehem            Shepherd Hotel            40
# 6                50      Bethlehem            Shepherd Hotel            40
# 7                50      Bethlehem            Shepherd Hotel            40
# 8                40      Bethlehem            Shepherd Hotel            40
# 9                30      Bethlehem            Shepherd Hotel            40
# 10               50      Bethlehem            Shepherd Hotel            40
# ...

# %%
hotels_df.groupby('hotel_locality').count()
# Out:
#                 review_rating  hotel_name  hotel_rating  num_reviews_reviewer  \
# hotel_locality
# Beit Jala                  51          51            51                    51
# Beit Sahour                16          16            16                    16
# Bethlehem                 722         722           722                   722
# Gaza City                  60          60            60                    60
# Jenin                       2           2             2                     2
# Jericho                   102         102           102                   102
# Nablus                     14          14            14                    14
# Ramallah                  186         186           186                   186
# Taybeh                     33          33            33                    33
#
#                 review_body  review_date  review_title  review_url  \
# hotel_locality
# Beit Jala                51           51            51          51
# ...

# %%
hotels_df.groupby('review_date').count()
# Out:
#              review_rating  hotel_locality  hotel_name  hotel_rating  \
# review_date
#  2005                    1               1           1             1
#  2009                    3               3           3             3
#  2010                    9               9           9             9
#  2011                   22              22          22            22
#  2012                   29              29          29            29
#  2013                   42              42          42            42
#  2014                   55              55          55            55
#  2015                   72              72          72            72
#  2016                  148             148         148           148
#  2017                  768             768         768           768
#  2018                   37              37          37            37
#
#              num_reviews_reviewer  review_body  review_title  review_url  \
# review_date
# ...

# %%
hotels_df.groupby('hotel_name').count()
# Out:
#                                            review_rating  hotel_locality  \
# hotel_name
# Al Deira                                              17              17
# Al-Mathaf Recreational and Cultural house             12              12
# Alexander Hotel                                       23              23
# Angel Hotel                                           51              51
# Ararat Hotel                                          24              24
# ArcMed Hotels Al Mashtal Gaza                          7               7
# Bethlehem Hotel                                       36              36
# Bethlehem Star Hotel                                  35              35
# Blue Beach Resort                                      3               3
# Caesar Hotel                                          10              10
# Caritas Betharram Center                               3               3
# Casablanca Hotel Ramallah                              6               6
# ...

# %%
hotels_df.groupby('review_rating').count()
# Out:
#                hotel_locality  hotel_name  hotel_rating  num_reviews_reviewer  \
# review_rating
# 10                         35          35            35                    35
# 20                         33          33            33                    33
# 30                        261         261           261                   261
# 40                        448         448           448                   448
# 50                        409         409           409                   409
#
#                review_body  review_date  review_title  review_url  \
# review_rating
# 10                      35           35            35          35
# 20                      33           33            33          33
# 30                     261          261           261         261
# 40                     448          448           448         448
# 50                     409          409           409         409
#
#                reviewer_name  user_location
# review_rating
# ...

# %%
hotels_df.groupby('hotel_rating').count()
# Out:
#               review_rating  hotel_locality  hotel_name  num_reviews_reviewer  \
# hotel_rating
# 30                      179             179         179                   179
# 40                      849             849         849                   849
# 50                      158             158         158                   158
#
#               review_body  review_date  review_title  review_url  \
# hotel_rating
# 30                    179          179           179         179
# 40                    849          849           849         849
# 50                    158          158           158         158
#
#               reviewer_name  user_location
# hotel_rating
# 30                      179            179
# 40                      849            849
# 50                      158            158

# %%
hotels_df.to_csv('hotels3.csv')

# %%
hotels_df.groupby('reviewer_name').count()
# Out:
#                  Unnamed: 0  review_rating  hotel_locality  hotel_name  \
# reviewer_name
# 1234mini1234              1              1               1           1
# 2006barbara2006           1              1               1           1
# 43187Thomas_R             1              1               1           1
# 91markoo                  1              1               1           1
# 99hazel                   1              1               1           1
# AAA030                   11             11              11          11
# Adelina D                 1              1               1           1
# Adriana J                 4              4               4           4
# Aiman A                   1              1               1           1
# Akulon                    3              3               3           3
# Ala A                     1              1               1           1
# Aladino86                 1              1               1           1
# ...

# %%
hotels_df.groupby('hotel_name')

# %%
hotels_df.drop_duplicates(subset=None, keep='first', inplace=False)
# Out:
#       Unnamed: 0  review_rating hotel_locality                hotel_name  \
# 0              0             10      Bethlehem            Shepherd Hotel
# 1              1             30      Bethlehem            Shepherd Hotel
# 2              2             40      Bethlehem            Shepherd Hotel
# 3              3             50      Bethlehem            Shepherd Hotel
# 4              4             30      Bethlehem            Shepherd Hotel
# 5              5             50      Bethlehem            Shepherd Hotel
# 6              6             50      Bethlehem            Shepherd Hotel
# 7              7             50      Bethlehem            Shepherd Hotel
# 8              8             40      Bethlehem            Shepherd Hotel
# 9              9             30      Bethlehem            Shepherd Hotel
# 10            10             50      Bethlehem            Shepherd Hotel
# 11            11             20      Bethlehem            Shepherd Hotel
# ...

# %%
hotels_df = hotels_df.drop(['Unnamed: 0', 'review_title','review_url','reviewer_name','review_body'], axis=1)

# %%
hotels_df
# Out:
#       review_rating hotel_locality                hotel_name  hotel_rating  \
# 0                10      Bethlehem            Shepherd Hotel            40
# 1                30      Bethlehem            Shepherd Hotel            40
# 2                40      Bethlehem            Shepherd Hotel            40
# 3                50      Bethlehem            Shepherd Hotel            40
# 4                30      Bethlehem            Shepherd Hotel            40
# 5                50      Bethlehem            Shepherd Hotel            40
# 6                50      Bethlehem            Shepherd Hotel            40
# 7                50      Bethlehem            Shepherd Hotel            40
# 8                40      Bethlehem            Shepherd Hotel            40
# 9                30      Bethlehem            Shepherd Hotel            40
# 10               50      Bethlehem            Shepherd Hotel            40
# ...

# %%
def fix_rating(txt):
    try:
        return int(txt)/10
    except:
        return txt

# %%
hotels_df['review_rating'] = hotels_df['review_rating'].apply(fix_rating)

# %%
hotels_df
# Out:
#       review_rating hotel_locality                hotel_name  hotel_rating  \
# 0               1.0      Bethlehem            Shepherd Hotel            40
# 1               3.0      Bethlehem            Shepherd Hotel            40
# 2               4.0      Bethlehem            Shepherd Hotel            40
# 3               5.0      Bethlehem            Shepherd Hotel            40
# 4               3.0      Bethlehem            Shepherd Hotel            40
# 5               5.0      Bethlehem            Shepherd Hotel            40
# 6               5.0      Bethlehem            Shepherd Hotel            40
# 7               5.0      Bethlehem            Shepherd Hotel            40
# 8               4.0      Bethlehem            Shepherd Hotel            40
# 9               3.0      Bethlehem            Shepherd Hotel            40
# 10              5.0      Bethlehem            Shepherd Hotel            40
# ...

# %%
hotels_df['hotel_rating'] = hotels_df['hotel_rating'].apply(fix_rating)

# %%
hotels_df = hotels_df.drop('num_reviews_reviewer', axis=1)

# %%
hotels_df
# Out:
#       review_rating hotel_locality                hotel_name  hotel_rating  \
# 0               1.0      Bethlehem            Shepherd Hotel           4.0
# 1               3.0      Bethlehem            Shepherd Hotel           4.0
# 2               4.0      Bethlehem            Shepherd Hotel           4.0
# 3               5.0      Bethlehem            Shepherd Hotel           4.0
# 4               3.0      Bethlehem            Shepherd Hotel           4.0
# 5               5.0      Bethlehem            Shepherd Hotel           4.0
# 6               5.0      Bethlehem            Shepherd Hotel           4.0
# 7               5.0      Bethlehem            Shepherd Hotel           4.0
# 8               4.0      Bethlehem            Shepherd Hotel           4.0
# 9               3.0      Bethlehem            Shepherd Hotel           4.0
# 10              5.0      Bethlehem            Shepherd Hotel           4.0
# ...

# %%
cols = hotels_df.columns.tolist()

# %%
cols
# Out:
# ['review_rating',
#  'hotel_locality',
#  'hotel_name',
#  'hotel_rating',
#  'review_date',
#  'user_location']

# %%
cols = [
 'hotel_name',
'hotel_locality',
 'hotel_rating',
 'review_date',
    'review_rating',
 'user_location']

# %%
hotels_df = hotels_df[cols]

# %%
hotels_df
# Out:
#                     hotel_name hotel_locality  hotel_rating  review_date  \
# 0               Shepherd Hotel      Bethlehem           4.0         2018
# 1               Shepherd Hotel      Bethlehem           4.0         2017
# 2               Shepherd Hotel      Bethlehem           4.0         2017
# 3               Shepherd Hotel      Bethlehem           4.0         2017
# 4               Shepherd Hotel      Bethlehem           4.0         2016
# 5               Shepherd Hotel      Bethlehem           4.0         2016
# 6               Shepherd Hotel      Bethlehem           4.0         2016
# 7               Shepherd Hotel      Bethlehem           4.0         2015
# 8               Shepherd Hotel      Bethlehem           4.0         2015
# 9               Shepherd Hotel      Bethlehem           4.0         2015
# 10              Shepherd Hotel      Bethlehem           4.0         2015
# 11              Shepherd Hotel      Bethlehem           4.0         2015
# ...

# %%
hotels_df.to_csv('hotels4.csv')

# %%
from ggplot import *

# %%
ggplot(aes(x='factor(hotel_locality)', fill='factor(review_rating)'), data=hotels_df) + \
    geom_bar()
# Out:
# /Users/mohammedissa/anaconda/lib/python3.6/site-packages/ggplot/ggplot.py:602: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   fill_levels = self.data[[fillcol_raw, fillcol]].sort(fillcol_raw)[fillcol].unique()
# <ggplot: (297679066)>

# %%
ggplot(aes(x='factor(hotel_rating)', fill='factor(review_rating)'), data=hotels_df) + \
    geom_bar()
# Out:
# /Users/mohammedissa/anaconda/lib/python3.6/site-packages/ggplot/ggplot.py:602: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   fill_levels = self.data[[fillcol_raw, fillcol]].sort(fillcol_raw)[fillcol].unique()
# <ggplot: (299659847)>

# %%
ggplot(hotels_df,aes('review_date')) + geom_histogram(fill='blue',bins=30,alpha=0.5)
# Out:
# <ggplot: (-9223372036556288526)>

# %%
ggplot(hotels_df,'factor(hotel_rating)') + geom_histogram(fill='blue',bins=150,alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-3c1c63c7bab8> in <module>()
# ----> 1 ggplot(hotels_df,'factor(hotel_rating)') + geom_histogram(fill='blue',bins=150,alpha=0.5)
#
# /Users/mohammedissa/anaconda/lib/python3.6/site-packages/ggplot/ggplot.py in __init__(self, aesthetics, data)
#      53         self._aes = aesthetics
#      54         self.data = data.copy()
# ---> 55         self._handle_index()
#      56         self.data = self._aes._evaluate_expressions(self.data)
#      57         self.data = self._aes.handle_identity_values(self.data)
#
# /Users/mohammedissa/anaconda/lib/python3.6/site-packages/ggplot/ggplot.py in _handle_index(self)
#     132
#     133     def _handle_index(self):
# --> 134         if '__index__' in self._aes.values():
#     135             self.data['__index__'] = self.data.index
#     136
#
# ...

# %%
summary(hotels_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-d5962dc6de96> in <module>()
# ----> 1 summary(hotels_df)
#
# NameError: name 'summary' is not defined

# %%
library(ggplot2)
library(ggthemes)
library(dplyr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-d9e77bfad3a7> in <module>()
# ----> 1 library(ggplot2)
#       2 library(ggthemes)
#       3 library(dplyr)
#
# NameError: name 'library' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
hotels_df
# Out:
#                     hotel_name hotel_locality  hotel_rating  review_date  \
# 0               Shepherd Hotel      Bethlehem           4.0         2018
# 1               Shepherd Hotel      Bethlehem           4.0         2017
# 2               Shepherd Hotel      Bethlehem           4.0         2017
# 3               Shepherd Hotel      Bethlehem           4.0         2017
# 4               Shepherd Hotel      Bethlehem           4.0         2016
# 5               Shepherd Hotel      Bethlehem           4.0         2016
# 6               Shepherd Hotel      Bethlehem           4.0         2016
# 7               Shepherd Hotel      Bethlehem           4.0         2015
# 8               Shepherd Hotel      Bethlehem           4.0         2015
# 9               Shepherd Hotel      Bethlehem           4.0         2015
# 10              Shepherd Hotel      Bethlehem           4.0         2015
# 11              Shepherd Hotel      Bethlehem           4.0         2015
# ...

# %%
plt.figure(figsize=(170,90))
sns.countplot(x='user_location',data=hotels_df,palette='Set1')

# %%
sns.stripplot(x="review_rating", y="review_date", data=hotels_df);

# %%
sns.boxplot(x="review_date", y="review_rating", data=hotels_df)

# %%
sns.countplot(x="review_date", data=hotels_df, palette="Greens_d");

# %%
sns.countplot(x="hotel_locality",hue='hotel_rating', data=hotels_df, palette="Greens_d");

# %%
hotels_df
# Out:
#                     hotel_name hotel_locality  hotel_rating  review_date  \
# 0               Shepherd Hotel      Bethlehem           4.0         2018
# 1               Shepherd Hotel      Bethlehem           4.0         2017
# 2               Shepherd Hotel      Bethlehem           4.0         2017
# 3               Shepherd Hotel      Bethlehem           4.0         2017
# 4               Shepherd Hotel      Bethlehem           4.0         2016
# 5               Shepherd Hotel      Bethlehem           4.0         2016
# 6               Shepherd Hotel      Bethlehem           4.0         2016
# 7               Shepherd Hotel      Bethlehem           4.0         2015
# 8               Shepherd Hotel      Bethlehem           4.0         2015
# 9               Shepherd Hotel      Bethlehem           4.0         2015
# 10              Shepherd Hotel      Bethlehem           4.0         2015
# 11              Shepherd Hotel      Bethlehem           4.0         2015
# ...

# %%
sns.countplot(x="review_date",hue='review_rating', data=hotels_df, palette="Greens_d");

# %%
sns.swarmplot(x="hotel_locality", y="review_rating", data=hotels_df);

# %%
def satisfaction(txt):    
    if int(txt) > 3:
        return 'positive'
    else:
        return 'negative'

# %%
hotels_df['satisfaction'] = hotels_df['review_rating'].apply(satisfaction)

# %%
hotels_df
# Out:
#                     hotel_name hotel_locality  hotel_rating  review_date  \
# 0               Shepherd Hotel      Bethlehem           4.0         2018
# 1               Shepherd Hotel      Bethlehem           4.0         2017
# 2               Shepherd Hotel      Bethlehem           4.0         2017
# 3               Shepherd Hotel      Bethlehem           4.0         2017
# 4               Shepherd Hotel      Bethlehem           4.0         2016
# 5               Shepherd Hotel      Bethlehem           4.0         2016
# 6               Shepherd Hotel      Bethlehem           4.0         2016
# 7               Shepherd Hotel      Bethlehem           4.0         2015
# 8               Shepherd Hotel      Bethlehem           4.0         2015
# 9               Shepherd Hotel      Bethlehem           4.0         2015
# 10              Shepherd Hotel      Bethlehem           4.0         2015
# 11              Shepherd Hotel      Bethlehem           4.0         2015
# ...

# %%
hotels_df = hotels_df[hotels_df.review_date != 2009]

# %%
sns.countplot(x="review_date",hue='satisfaction', data=hotels_df, palette="Greens_d");

# %%
import numpy as np

# %%
rate = (hotels_df['satisfaction']).sum()

# %%
df = hotels_df.groupby(by=['review_date', 'satisfaction'])['satisfaction'].count()

# %%
df
# Out:
# review_date  satisfaction
# 2010         negative          3
#              positive          6
# 2011         negative          2
#              positive         18
# 2012         negative          1
#              positive         22
# 2013         negative          2
#              positive         33
# 2014         negative          2
#              positive         48
# 2015         negative         10
#              positive         53
# 2016         negative         17
#              positive        114
# 2017         negative         30
#              positive        534
# Name: satisfaction, dtype: int64

# %%
ff = hotels_df.groupby(by=['user_location']).count()

# %%
df = hotels_df['user_location'].value_counts().sort

# %%
def fixstr(txt):
    return txt.strip()

# %%
hotels_df['user_location'] = hotels_df['user_location'].apply(fixstr)

# %%
df = pd.Series(df)

# %%
df
# Out:
# <bound method Series.sort of United Kingdom             169
# Palestinian Territories     50
# Israel                      48
# Ukraine                     41
# Australia                   33
# England                     32
# The Netherlands             28
# Romania                     28
# New York                    24
# India                       21
# Germany                     21
# Norway                      20
# Poland                      19
# California                  19
# Birmingham                  18
# Florida                     15
# Greece                      14
# Puerto Rico                 14
# Colorado                    14
# القدس                       13
# Jordan                      13
# Limassol                    13
# Lokeren                     11
# Illinois                    10
# Canada                       9
# Palestine                    8
# Italy                        8
# Ohio                         6
# Texas                        6
# ...
